# %% [markdown]
# # Adult Income Dataset

# %%
import numpy as np 
import pandas as pd 
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("../../InputData/AdultDataset/adult.csv")
data.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2  Married-civ-spouse    Protective-serv        Husband  White    Male
# 3  Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 4       Never-married                  ?      Own-child  White  Female
# 5       Never-married      Other-service  Not-in-family  White    Male
# 6       Never-married                  ?      Unmarried  Black    Male
# 7  Married-civ-spouse     Prof-specialty        Husband  White    Male
# 8       Never-married      Other-service      Unmarried  White  Female
# 9  Married-civ-spouse       Craft-repair        Husband  White    Male
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0             0             0              40  United-States  <=50K
# 1             0             0              50  United-States  <=50K
# 2             0             0              40  United-States   >50K
# 3          7688             0              40  United-States   >50K
# 4             0             0              30  United-States  <=50K
# 5             0             0              30  United-States  <=50K
# 6             0             0              40  United-States  <=50K
# 7          3103             0              32  United-States   >50K
# 8             0             0              40  United-States  <=50K
# 9             0             0              10  United-States  <=50K

# %% [markdown]
# ## Data Cleaning

# %%
# find columns with "?" value
col_names = data.columns
num_data = data.shape[0]
for c in col_names:
    num_non = data[c].isin(["?"]).sum()
    if num_non > 0:
        print (c)
        print (num_non)
        print ("{0:.2f}%".format(float(num_non) / num_data * 100))
        print ("\n")
# Out:
# workclass
# 2799
# 5.73%
#
#
# occupation
# 2809
# 5.75%
#
#
# native-country
# 857
# 1.75%

# %%
data = data[data["workclass"] != "?"]
data = data[data["occupation"] != "?"]
data = data[data["native-country"] != "?"]

data.shape
# Out:
# (45222, 15)

# %%
data.to_csv(r"../../InputData/AdultDataset/ForClassification/CleanAdult.csv")

# %%
# change categorical values to numeric
# education and education-num are the same, one-to-one mapping
category_col =['workclass', 'race', 'education','marital-status', 'occupation',
               'relationship', 'gender', 'native-country', 'income'] 

for col in category_col:
    b, c = np.unique(data[col], return_inverse=True) 
    data[col] = c

data.head()
# Out:
#    age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0   25          2  226802          1                7               4
# 1   38          2   89814         11                9               2
# 2   28          1  336951          7               12               2
# 3   44          2  160323         15               10               2
# 5   34          2  198693          0                6               4
#
#    occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0           6             3     2       1             0             0
# 1           4             0     4       1             0             0
# 2          10             0     4       1             0             0
# 3           6             0     2       1          7688             0
# 5           7             1     4       1             0             0
#
#    hours-per-week  native-country  income
# 0              40              38       0
# 1              50              38       0
# 2              40              38       1
# 3              40              38       1
# 5              30              38       0

# %%
data.to_csv(r"../../InputData/AdultDataset/ForClassification/CleanAdult_numerical.csv", index=False)

# %% [markdown]
# ## Prediction

# %%
predictors = ['age','workclass','education','educational-num',
              'marital-status', 'occupation','relationship','race','gender',
              'capital-gain','capital-loss','hours-per-week', 'native-country']

high_income = data[data['income'] == 1]
low_income = data[data['income'] == 0]



X_train, X_test, y_train, y_test = train_test_split(data[predictors], data['income'], test_size=0.5, random_state=1)

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %%
num = 0
for index, row in X_test.iterrows():
    if clf.predict([row.to_list()]) != y_test.loc[index]:
        num = num + 1
        print ('-----------------')
        print (str(num) + '\n')
        print (row)
        
print(num)
print((1-num/len(X_test))*100)
# Out:
# -----------------
# 1
#
# age                  40
# workclass             2
# education            15
# educational-num      10
# marital-status        4
# occupation            3
# relationship          1
# race                  4
# gender                0
# capital-gain          0
# capital-loss       1340
# hours-per-week       40
# native-country       38
# Name: 9107, dtype: int64
# -----------------
# 2
#
# age                43
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation         13
# relationship        0
# race                1
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     99
# native-country     38
# Name: 35162, dtype: int64
# -----------------
# 3
#
# age                34
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 9231, dtype: int64
# -----------------
# 4
#
# age                33
# workclass           2
# education          12
# educational-num    14
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     45
# native-country     38
# Name: 42467, dtype: int64
# -----------------
# 5
#
# age                40
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 40753, dtype: int64
# -----------------
# 6
#
# age                29
# workclass           0
# education          15
# educational-num    10
# marital-status      4
# occupation          7
# relationship        1
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 40238, dtype: int64
# -----------------
# 7
#
# age                  33
# workclass             2
# education            11
# educational-num       9
# marital-status        2
# occupation           11
# relationship          0
# race                  4
# gender                1
# capital-gain          0
# capital-loss       1672
# hours-per-week       55
# native-country       38
# Name: 37051, dtype: int64
# -----------------
# 8
#
# age                34
# workclass           3
# education           9
# educational-num    13
# marital-status      4
# occupation          9
# relationship        1
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     62
# native-country     38
# Name: 44375, dtype: int64
# -----------------
# 9
#
# age                29
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 46327, dtype: int64
# -----------------
# 10
#
# age                44
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation         13
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 29258, dtype: int64
# -----------------
# 11
#
# age                63
# workclass           4
# education          14
# educational-num    15
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     30
# native-country     38
# Name: 43895, dtype: int64
# -----------------
# 12
#
# age                33
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          0
# relationship        5
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 411, dtype: int64
# -----------------
# 13
#
# age                42
# workclass           4
# education           9
# educational-num    13
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     52
# native-country     38
# Name: 10434, dtype: int64
# -----------------
# 14
#
# age                40
# workclass           2
# education           9
# educational-num    13
# marital-status      0
# occupation          3
# relationship        1
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     55
# native-country     38
# Name: 6140, dtype: int64
# -----------------
# 15
#
# age                54
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation          9
# relationship        0
# race                2
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     56
# native-country     13
# Name: 37405, dtype: int64
# -----------------
# 16
#
# age                38
# workclass           2
# education           8
# educational-num    11
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 28158, dtype: int64
# -----------------
# 17
#
# age                36
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 24560, dtype: int64
# -----------------
# 18
#
# age                59
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation          5
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     21
# Name: 35629, dtype: int64
# -----------------
# 19
#
# age                47
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          7
# relationship        5
# race                2
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     30
# native-country     38
# Name: 34369, dtype: int64
# -----------------
# 20
#
# age                52
# workclass           2
# education           6
# educational-num     5
# marital-status      0
# occupation          2
# relationship        4
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country      4
# Name: 19792, dtype: int64
# -----------------
# 21
#
# age                53
# workclass           2
# education          15
# educational-num    10
# marital-status      4
# occupation          3
# relationship        1
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 6772, dtype: int64
# -----------------
# 22
#
# age                32
# workclass           2
# education           8
# educational-num    11
# marital-status      0
# occupation         11
# relationship        1
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 17713, dtype: int64
# -----------------
# 23
#
# age                30
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation          7
# relationship        5
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 18586, dtype: int64
# -----------------
# 24
#
# age                45
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation         13
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 45848, dtype: int64
# -----------------
# 25
#
# age                  66
# workclass             2
# education            12
# educational-num      14
# marital-status        2
# occupation            9
# relationship          0
# race                  4
# gender                1
# capital-gain       2936
# capital-loss          0
# hours-per-week       20
# native-country       38
# Name: 27497, dtype: int64
# -----------------
# 26
#
# age                51
# workclass           5
# education           9
# educational-num    13
# marital-status      2
# occupation          9
# relationship        0
# race                2
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 4543, dtype: int64
# -----------------
# 27
#
# age                40
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation         13
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 42404, dtype: int64
# -----------------
# 28
#
# age                43
# workclass           0
# education           9
# educational-num    13
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 36754, dtype: int64
# -----------------
# 29
#
# age                45
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 28090, dtype: int64
# -----------------
# 30
#
# age                29
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation          9
# relationship        5
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 47868, dtype: int64
# -----------------
# 31
#
# age                57
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          2
# relationship        0
# race                2
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     48
# native-country     38
# Name: 134, dtype: int64
# -----------------
# 32
#
# age                57
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 37987, dtype: int64
# -----------------
# 33
#
# age                30
# workclass           4
# education           7
# educational-num    12
# marital-status      4
# occupation          2
# relationship        3
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 46821, dtype: int64
# -----------------
# 34
#
# age                42
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     60
# native-country     38
# Name: 42955, dtype: int64
# -----------------
# 35
#
# age                30
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     45
# native-country     38
# Name: 2870, dtype: int64
# -----------------
# 36
#
# age                40
# workclass           2
# education           0
# educational-num     6
# marital-status      5
# occupation         13
# relationship        4
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     70
# native-country     38
# Name: 10913, dtype: int64
# -----------------
# 37
#
# age                43
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     44
# native-country     38
# Name: 33777, dtype: int64
# -----------------
# 38
#
# age                  42
# workclass             3
# education             9
# educational-num      13
# marital-status        0
# occupation           12
# relationship          1
# race                  4
# gender                0
# capital-gain          0
# capital-loss       1564
# hours-per-week       60
# native-country       38
# Name: 8601, dtype: int64
# -----------------
# 39
#
# age                28
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation          3
# relationship        0
# race                1
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     29
# Name: 26308, dtype: int64
# -----------------
# 40
#
# age                47
# workclass           1
# education          12
# educational-num    14
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 858, dtype: int64
# -----------------
# 41
#
# age                38
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 22545, dtype: int64
# -----------------
# 42
#
# age                36
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     55
# native-country     38
# Name: 45546, dtype: int64
# -----------------
# 43
#
# age                36
# workclass           0
# education           7
# educational-num    12
# marital-status      2
# occupation          0
# relationship        5
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 17718, dtype: int64
# -----------------
# 44
#
# age                35
# workclass           3
# education           9
# educational-num    13
# marital-status      5
# occupation          9
# relationship        1
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 46093, dtype: int64
# -----------------
# 45
#
# age                57
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          6
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 1937, dtype: int64
# -----------------
# 46
#
# age                64
# workclass           2
# education           5
# educational-num     4
# marital-status      2
# occupation          4
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 28845, dtype: int64
# -----------------
# 47
#
# age                23
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation          3
# relationship        5
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     45
# native-country     38
# Name: 8963, dtype: int64
# -----------------
# 48
#
# age                35
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     60
# native-country     38
# Name: 19083, dtype: int64
# -----------------
# 49
#
# age                24
# workclass           5
# education          10
# educational-num    16
# marital-status      4
# occupation          9
# relationship        1
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     99
# native-country      8
# Name: 29069, dtype: int64
# -----------------
# 50
#
# age                40
# workclass           2
# education           9
# educational-num    13
# marital-status      4
# occupation         11
# relationship        1
# race                3
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     55
# native-country     38
# Name: 17065, dtype: int64
# -----------------
# 51
#
# age                46
# workclass           2
# education           5
# educational-num     4
# marital-status      2
# occupation         11
# relationship        5
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     30
# native-country     38
# Name: 13476, dtype: int64
# -----------------
# 52
#
# age                54
# workclass           2
# education          12
# educational-num    14
# marital-status      5
# occupation          3
# relationship        1
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 2419, dtype: int64
# -----------------
# 53
#
# age                79
# workclass           3
# education           9
# educational-num    13
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     20
# native-country     38
# Name: 42523, dtype: int64
# -----------------
# 54
#
# age                36
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation          4
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     56
# native-country     38
# Name: 9513, dtype: int64
# -----------------
# 55
#
# age                51
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 16852, dtype: int64
# -----------------
# 56
#
# age                38
# workclass           1
# education          11
# educational-num     9
# marital-status      2
# occupation         13
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     20
# native-country     38
# Name: 37279, dtype: int64
# -----------------
# 57
#
# age                36
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation          0
# relationship        5
# race                1
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     29
# Name: 3693, dtype: int64
# -----------------
# 58
#
# age                27
# workclass           4
# education          15
# educational-num    10
# marital-status      2
# occupation          3
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     45
# native-country     38
# Name: 29675, dtype: int64
# -----------------
# 59
#
# age                52
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          4
# relationship        0
# race                3
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     49
# native-country     25
# Name: 21309, dtype: int64
# -----------------
# 60
#
# age                33
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation          0
# relationship        5
# race                2
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     30
# native-country     38
# Name: 23715, dtype: int64
# -----------------
# 61
#
# age                34
# workclass           5
# education           9
# educational-num    13
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 9483, dtype: int64
# -----------------
# 62
#
# age                36
# workclass           4
# education           9
# educational-num    13
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     10
# Name: 2395, dtype: int64
# -----------------
# 63
#
# age                38
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation          0
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     45
# native-country     38
# Name: 12629, dtype: int64
# -----------------
# 64
#
# age                31
# workclass           4
# education          11
# educational-num     9
# marital-status      2
# occupation          3
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 3114, dtype: int64
# -----------------
# 65
#
# age                37
# workclass           0
# education          11
# educational-num     9
# marital-status      2
# occupation          0
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 30075, dtype: int64
# -----------------
# 66
#
# age                42
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation         12
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 47791, dtype: int64
# -----------------
# 67
#
# age                35
# workclass           2
# education          12
# educational-num    14
# marital-status      4
# occupation          9
# relationship        1
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     45
# native-country     38
# Name: 17521, dtype: int64
# -----------------
# 68
#
# age                37
# workclass           2
# education           8
# educational-num    11
# marital-status      2
# occupation         12
# relationship        5
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     37
# native-country     38
# Name: 31523, dtype: int64
# -----------------
# 69
#
# age                49
# workclass           2
# education           5
# educational-num     4
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 7948, dtype: int64
# -----------------
# 70
#
# age                38
# workclass           4
# education          12
# educational-num    14
# marital-status      4
# occupation          9
# relationship        1
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 28242, dtype: int64
# -----------------
# 71
#
# age                51
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 18526, dtype: int64
# -----------------
# 72
#
# age                46
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          6
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 27087, dtype: int64
# -----------------
# 73
#
# age                57
# workclass           3
# education          15
# educational-num    10
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 30955, dtype: int64
# -----------------
# 74
#
# age                34
# workclass           2
# education           7
# educational-num    12
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     38
# native-country     38
# Name: 4938, dtype: int64
# -----------------
# 75
#
# age                48
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 46653, dtype: int64
# -----------------
# 76
#
# age                31
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 14719, dtype: int64
# -----------------
# 77
#
# age                43
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 28797, dtype: int64
# -----------------
# 78
#
# age                44
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          2
# relationship        0
# race                2
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 9970, dtype: int64
# -----------------
# 79
#
# age                58
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          8
# relationship        2
# race                1
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     60
# native-country     29
# Name: 39888, dtype: int64
# -----------------
# 80
#
# age                28
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 6350, dtype: int64
# -----------------
# 81
#
# age                30
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation          3
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 40077, dtype: int64
# -----------------
# 82
#
# age                44
# workclass           5
# education           8
# educational-num    11
# marital-status      2
# occupation         10
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 1708, dtype: int64
# -----------------
# 83
#
# age                22
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation         13
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 30965, dtype: int64
# -----------------
# 84
#
# age                33
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          9
# relationship        0
# race                0
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     48
# native-country     38
# Name: 21639, dtype: int64
# -----------------
# 85
#
# age                50
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation         11
# relationship        5
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     39
# native-country     38
# Name: 47403, dtype: int64
# -----------------
# 86
#
# age                22
# workclass           2
# education          11
# educational-num     9
# marital-status      0
# occupation         12
# relationship        4
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     30
# native-country     10
# Name: 19180, dtype: int64
# -----------------
# 87
#
# age                50
# workclass           1
# education          12
# educational-num    14
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     70
# native-country     38
# Name: 10917, dtype: int64
# -----------------
# 88
#
# age                36
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     45
# native-country     38
# Name: 3097, dtype: int64
# -----------------
# 89
#
# age                51
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation          0
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     38
# native-country     38
# Name: 6962, dtype: int64
# -----------------
# 90
#
# age                35
# workclass           4
# education          15
# educational-num    10
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 4884, dtype: int64
# -----------------
# 91
#
# age                38
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 26443, dtype: int64
# -----------------
# 92
#
# age                27
# workclass           1
# education          15
# educational-num    10
# marital-status      4
# occupation         10
# relationship        3
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 34551, dtype: int64
# -----------------
# 93
#
# age                52
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation          7
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     35
# native-country     38
# Name: 14190, dtype: int64
# -----------------
# 94
#
# age                36
# workclass           1
# education           7
# educational-num    12
# marital-status      4
# occupation          9
# relationship        3
# race                2
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 6812, dtype: int64
# -----------------
# 95
#
# age                35
# workclass           4
# education           9
# educational-num    13
# marital-status      4
# occupation          7
# relationship        1
# race                2
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     60
# native-country     38
# Name: 21827, dtype: int64
# -----------------
# 96
#
# age                40
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 31856, dtype: int64
# -----------------
# 97
#
# age                40
# workclass           2
# education           7
# educational-num    12
# marital-status      0
# occupation          3
# relationship        1
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 30051, dtype: int64
# -----------------
# 98
#
# age                  23
# workclass             2
# education            15
# educational-num      10
# marital-status        2
# occupation            6
# relationship          0
# race                  4
# gender                1
# capital-gain          0
# capital-loss       1902
# hours-per-week       40
# native-country       38
# Name: 18556, dtype: int64
# -----------------
# 99
#
# age                38
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation          3
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     30
# native-country     38
# Name: 14609, dtype: int64
# -----------------
# 100
#
# age                28
# workclass           2
# education          12
# educational-num    14
# marital-status      3
# occupation         11
# relationship        1
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     80
# native-country     38
# Name: 41955, dtype: int64
# -----------------
# 101
#
# age                59
# workclass           2
# education          12
# educational-num    14
# marital-status      0
# occupation          3
# relationship        1
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     45
# native-country     38
# Name: 9932, dtype: int64
# -----------------
# 102
#
# age                59
# workclass           2
# education           6
# educational-num     5
# marital-status      2
# occupation         13
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     60
# native-country     38
# Name: 21550, dtype: int64
# -----------------
# 103
#
# age                24
# workclass           5
# education          15
# educational-num    10
# marital-status      2
# occupation          9
# relationship        5
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 31549, dtype: int64
# -----------------
# 104
#
# age                  34
# workclass             2
# education            12
# educational-num      14
# marital-status        4
# occupation            9
# relationship          1
# race                  4
# gender                1
# capital-gain          0
# capital-loss       2258
# hours-per-week       50
# native-country       38
# Name: 37250, dtype: int64
# -----------------
# 105
#
# age                44
# workclass           2
# education          12
# educational-num    14
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 46516, dtype: int64
# -----------------
# 106
#
# age                43
# workclass           5
# education          15
# educational-num    10
# marital-status      2
# occupation         13
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     84
# native-country     38
# Name: 2215, dtype: int64
# -----------------
# 107
#
# age                42
# workclass           4
# education          15
# educational-num    10
# marital-status      4
# occupation          3
# relationship        1
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 3522, dtype: int64
# -----------------
# 108
#
# age                35
# workclass           2
# education           8
# educational-num    11
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     42
# native-country     38
# Name: 8063, dtype: int64
# -----------------
# 109
#
# age                24
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation         13
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     70
# native-country     38
# Name: 18827, dtype: int64
# -----------------
# 110
#
# age                47
# workclass           2
# education           8
# educational-num    11
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 42663, dtype: int64
# -----------------
# 111
#
# age                26
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 9799, dtype: int64
# -----------------
# 112
#
# age                31
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          5
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 22511, dtype: int64
# -----------------
# 113
#
# age                47
# workclass           5
# education          15
# educational-num    10
# marital-status      2
# occupation          7
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     38
# native-country     38
# Name: 48215, dtype: int64
# -----------------
# 114
#
# age                42
# workclass           4
# education          12
# educational-num    14
# marital-status      0
# occupation          3
# relationship        4
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     70
# native-country     38
# Name: 10319, dtype: int64
# -----------------
# 115
#
# age                31
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     65
# native-country     38
# Name: 46996, dtype: int64
# -----------------
# 116
#
# age                54
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 26698, dtype: int64
# -----------------
# 117
#
# age                38
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation         13
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 9467, dtype: int64
# -----------------
# 118
#
# age                34
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation          0
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 21738, dtype: int64
# -----------------
# 119
#
# age                40
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 2860, dtype: int64
# -----------------
# 120
#
# age                61
# workclass           1
# education           9
# educational-num    13
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     42
# native-country     38
# Name: 33383, dtype: int64
# -----------------
# 121
#
# age                39
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          0
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 11852, dtype: int64
# -----------------
# 122
#
# age                46
# workclass           5
# education          11
# educational-num     9
# marital-status      2
# occupation          7
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     43
# native-country     38
# Name: 20021, dtype: int64
# -----------------
# 123
#
# age                58
# workclass           4
# education          11
# educational-num     9
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     72
# native-country     38
# Name: 32090, dtype: int64
# -----------------
# 124
#
# age                41
# workclass           4
# education          11
# educational-num     9
# marital-status      2
# occupation          7
# relationship        5
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     20
# native-country     38
# Name: 16522, dtype: int64
# -----------------
# 125
#
# age                51
# workclass           4
# education          15
# educational-num    10
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 5447, dtype: int64
# -----------------
# 126
#
# age                54
# workclass           2
# education          14
# educational-num    15
# marital-status      4
# occupation          9
# relationship        2
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     65
# native-country     38
# Name: 32332, dtype: int64
# -----------------
# 127
#
# age                51
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation         13
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 42174, dtype: int64
# -----------------
# 128
#
# age                34
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation          9
# relationship        5
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 45992, dtype: int64
# -----------------
# 129
#
# age                36
# workclass           1
# education          15
# educational-num    10
# marital-status      2
# occupation         10
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     57
# native-country     38
# Name: 23661, dtype: int64
# -----------------
# 130
#
# age                41
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 33018, dtype: int64
# -----------------
# 131
#
# age                36
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation         13
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     70
# native-country     38
# Name: 7097, dtype: int64
# -----------------
# 132
#
# age                40
# workclass           2
# education           0
# educational-num     6
# marital-status      2
# occupation          6
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 17812, dtype: int64
# -----------------
# 133
#
# age                41
# workclass           0
# education          15
# educational-num    10
# marital-status      2
# occupation          3
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 10638, dtype: int64
# -----------------
# 134
#
# age                59
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          6
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 5616, dtype: int64
# -----------------
# 135
#
# age                35
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation          0
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 29550, dtype: int64
# -----------------
# 136
#
# age                56
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 29159, dtype: int64
# -----------------
# 137
#
# age                59
# workclass           3
# education          11
# educational-num     9
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 3347, dtype: int64
# -----------------
# 138
#
# age                52
# workclass           4
# education          11
# educational-num     9
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     60
# native-country     38
# Name: 2141, dtype: int64
# -----------------
# 139
#
# age                47
# workclass           0
# education          15
# educational-num    10
# marital-status      2
# occupation          3
# relationship        0
# race                2
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 33295, dtype: int64
# -----------------
# 140
#
# age                43
# workclass           2
# education           9
# educational-num    13
# marital-status      4
# occupation         11
# relationship        4
# race                2
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     35
# native-country     38
# Name: 47995, dtype: int64
# -----------------
# 141
#
# age                25
# workclass           2
# education           7
# educational-num    12
# marital-status      4
# occupation          9
# relationship        1
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 39996, dtype: int64
# -----------------
# 142
#
# age                57
# workclass           2
# education          12
# educational-num    14
# marital-status      0
# occupation          9
# relationship        1
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     30
# native-country     38
# Name: 46811, dtype: int64
# -----------------
# 143
#
# age                  33
# workclass             0
# education             9
# educational-num      13
# marital-status        4
# occupation           10
# relationship          1
# race                  4
# gender                1
# capital-gain          0
# capital-loss       1408
# hours-per-week       50
# native-country       38
# Name: 12810, dtype: int64
# -----------------
# 144
#
# age                36
# ...
# 4294
#
# age                54
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 39876, dtype: int64
# -----------------
# 4295
#
# age                31
# workclass           2
# education          11
# educational-num     9
# marital-status      4
# occupation          2
# relationship        1
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 34816, dtype: int64
# -----------------
# 4296
#
# age                  45
# workclass             2
# education             6
# educational-num       5
# marital-status        2
# occupation            7
# relationship          0
# race                  4
# gender                1
# capital-gain          0
# capital-loss       1848
# hours-per-week       40
# native-country       38
# Name: 34609, dtype: int64
# -----------------
# 4297
#
# age                  37
# workclass             2
# education             6
# educational-num       5
# marital-status        2
# occupation            5
# relationship          0
# race                  4
# gender                1
# capital-gain       3781
# capital-loss          0
# hours-per-week       50
# native-country       25
# Name: 18650, dtype: int64
# -----------------
# 4298
#
# age                33
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 41867, dtype: int64
# -----------------
# 4299
#
# age                46
# workclass           2
# education           9
# educational-num    13
# marital-status      0
# occupation         11
# relationship        4
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 40175, dtype: int64
# -----------------
# 4300
#
# age                47
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation          3
# relationship        0
# race                1
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 19429, dtype: int64
# -----------------
# 4301
#
# age                49
# workclass           4
# education           9
# educational-num    13
# marital-status      6
# occupation         11
# relationship        4
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 47541, dtype: int64
# -----------------
# 4302
#
# age                60
# workclass           4
# education          11
# educational-num     9
# marital-status      2
# occupation          4
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     65
# native-country     38
# Name: 8301, dtype: int64
# -----------------
# 4303
#
# age                33
# workclass           2
# education           8
# educational-num    11
# marital-status      2
# occupation          2
# relationship        0
# race                1
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     18
# Name: 9821, dtype: int64
# -----------------
# 4304
#
# age                34
# workclass           2
# education           8
# educational-num    11
# marital-status      2
# occupation          6
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 18686, dtype: int64
# -----------------
# 4305
#
# age                  31
# workclass             3
# education             9
# educational-num      13
# marital-status        2
# occupation           11
# relationship          0
# race                  4
# gender                1
# capital-gain       3908
# capital-loss          0
# hours-per-week       50
# native-country       38
# Name: 42055, dtype: int64
# -----------------
# 4306
#
# age                32
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 1705, dtype: int64
# -----------------
# 4307
#
# age                30
# workclass           2
# education           8
# educational-num    11
# marital-status      2
# occupation         12
# relationship        2
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country      1
# Name: 18753, dtype: int64
# -----------------
# 4308
#
# age                53
# workclass           2
# education          15
# educational-num    10
# marital-status      2
# occupation         13
# relationship        0
# race                3
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     60
# native-country     38
# Name: 13721, dtype: int64
# -----------------
# 4309
#
# age                51
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation         12
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 38938, dtype: int64
# -----------------
# 4310
#
# age                48
# workclass           2
# education           9
# educational-num    13
# marital-status      0
# occupation         11
# relationship        1
# race                2
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 41418, dtype: int64
# -----------------
# 4311
#
# age                33
# workclass           2
# education           8
# educational-num    11
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     45
# native-country     38
# Name: 4343, dtype: int64
# -----------------
# 4312
#
# age                  63
# workclass             2
# education            15
# educational-num      10
# marital-status        2
# occupation           11
# relationship          0
# race                  4
# gender                1
# capital-gain       5013
# capital-loss          0
# hours-per-week       15
# native-country       38
# Name: 6367, dtype: int64
# -----------------
# 4313
#
# age                39
# workclass           2
# education          15
# educational-num    10
# marital-status      0
# occupation          0
# relationship        1
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     60
# native-country     38
# Name: 30184, dtype: int64
# -----------------
# 4314
#
# age                30
# workclass           1
# education          15
# educational-num    10
# marital-status      2
# occupation         10
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 13999, dtype: int64
# -----------------
# 4315
#
# age                31
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 31951, dtype: int64
# -----------------
# 4316
#
# age                37
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation          3
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     45
# native-country     38
# Name: 17128, dtype: int64
# -----------------
# 4317
#
# age                47
# workclass           1
# education          14
# educational-num    15
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     35
# native-country     38
# Name: 14469, dtype: int64
# -----------------
# 4318
#
# age                27
# workclass           4
# education          11
# educational-num     9
# marital-status      2
# occupation          7
# relationship        0
# race                2
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     60
# native-country     38
# Name: 46750, dtype: int64
# -----------------
# 4319
#
# age                41
# workclass           1
# education          12
# educational-num    14
# marital-status      4
# occupation          9
# relationship        1
# race                2
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 22757, dtype: int64
# -----------------
# 4320
#
# age                  45
# workclass             2
# education             8
# educational-num      11
# marital-status        4
# occupation            9
# relationship          1
# race                  4
# gender                0
# capital-gain          0
# capital-loss       1564
# hours-per-week       40
# native-country       38
# Name: 16424, dtype: int64
# -----------------
# 4321
#
# age                47
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          8
# relationship        5
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     35
# native-country     38
# Name: 2471, dtype: int64
# -----------------
# 4322
#
# age                35
# workclass           1
# education          12
# educational-num    14
# marital-status      4
# occupation          9
# relationship        1
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     60
# native-country     38
# Name: 28128, dtype: int64
# -----------------
# 4323
#
# age                40
# workclass           3
# education          12
# educational-num    14
# marital-status      2
# occupation          9
# relationship        0
# race                2
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     55
# native-country     37
# Name: 5747, dtype: int64
# -----------------
# 4324
#
# age                33
# workclass           2
# education           1
# educational-num     7
# marital-status      5
# occupation          3
# relationship        4
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     30
# native-country     38
# Name: 13298, dtype: int64
# -----------------
# 4325
#
# age                53
# workclass           1
# education          14
# educational-num    15
# marital-status      0
# occupation          9
# relationship        1
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     50
# native-country     38
# Name: 18261, dtype: int64
# -----------------
# 4326
#
# age                43
# workclass           1
# education           8
# educational-num    11
# marital-status      2
# occupation          3
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 45731, dtype: int64
# -----------------
# 4327
#
# age                44
# workclass           0
# education          11
# educational-num     9
# marital-status      2
# occupation         13
# relationship        0
# race                2
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     60
# native-country     38
# Name: 8865, dtype: int64
# -----------------
# 4328
#
# age                37
# workclass           4
# education          11
# educational-num     9
# marital-status      2
# occupation          9
# relationship        5
# race                4
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     35
# native-country     38
# Name: 26222, dtype: int64
# -----------------
# 4329
#
# age                42
# workclass           2
# education           7
# educational-num    12
# marital-status      2
# occupation          3
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 17240, dtype: int64
# -----------------
# 4330
#
# age                38
# workclass           4
# education           1
# educational-num     7
# marital-status      2
# occupation          7
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     60
# native-country     38
# Name: 11534, dtype: int64
# -----------------
# 4331
#
# age                58
# workclass           2
# education           9
# educational-num    13
# marital-status      2
# occupation         11
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 1526, dtype: int64
# -----------------
# 4332
#
# age                  44
# workclass             4
# education             9
# educational-num      13
# marital-status        2
# occupation            3
# relationship          0
# race                  4
# gender                1
# capital-gain          0
# capital-loss       2415
# hours-per-week       50
# native-country       38
# Name: 33397, dtype: int64
# -----------------
# 4333
#
# age                45
# workclass           4
# education           9
# educational-num    13
# marital-status      2
# occupation          9
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 41059, dtype: int64
# -----------------
# 4334
#
# age                42
# workclass           2
# education          15
# educational-num    10
# marital-status      6
# occupation          3
# relationship        1
# race                0
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     38
# Name: 43182, dtype: int64
# -----------------
# 4335
#
# age                41
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          7
# relationship        0
# race                0
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     45
# native-country     38
# Name: 23033, dtype: int64
# -----------------
# 4336
#
# age                36
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          2
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country     32
# Name: 461, dtype: int64
# -----------------
# 4337
#
# age                  66
# workclass             2
# education            15
# educational-num      10
# marital-status        2
# occupation           13
# relationship          0
# race                  4
# gender                1
# capital-gain          0
# capital-loss       1258
# hours-per-week       20
# native-country       38
# Name: 42946, dtype: int64
# -----------------
# 4338
#
# age                48
# workclass           2
# education          11
# educational-num     9
# marital-status      2
# occupation          6
# relationship        0
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     40
# native-country      5
# Name: 1014, dtype: int64
# -----------------
# 4339
#
# age                53
# workclass           2
# education           9
# educational-num    13
# marital-status      0
# occupation          3
# relationship        1
# race                4
# gender              1
# capital-gain        0
# capital-loss        0
# hours-per-week     70
# native-country     38
# Name: 18325, dtype: int64
# -----------------
# 4340
#
# age                  27
# workclass             0
# education             7
# educational-num      12
# marital-status        2
# occupation            0
# relationship          0
# race                  4
# gender                1
# capital-gain       4064
# capital-loss          0
# hours-per-week       40
# native-country        7
# Name: 31432, dtype: int64
# 4340
# 80.8058024855159

# %%
X_test_res = X_test.copy()

# %%
X_test_res['act'] = y_test

# %%
X_test_res
# Out:
#        age  workclass  education  educational-num  marital-status  occupation  \
# 42093   64          2         15               10               3           3
# 31739   56          2          6                5               0           0
# 10773   36          2          6                5               2           5
# 15850   19          2         11                9               4           5
# 40645   32          2          7               12               2           9
# ...    ...        ...        ...              ...             ...         ...
# 34408   36          2         11                9               0           6
# 13238   41          4         15               10               2           2
# 31432   27          0          7               12               2           0
# 19093   40          2         11                9               2          11
# 36935   57          4         15               10               5          11
#
#        relationship  race  gender  capital-gain  capital-loss  hours-per-week  \
# 42093             4     4       0             0             0              40
# 31739             1     4       1             0             0              40
# 10773             0     4       1             0             0              60
# 15850             1     2       1             0             0              37
# 40645             0     4       1             0             0              45
# ...             ...   ...     ...           ...           ...             ...
# 34408             4     4       1             0             0              40
# 13238             0     4       1             0             0              40
# 31432             0     4       1          4064             0              40
# 19093             5     4       0          5013             0              20
# 36935             1     4       1             0             0              35
#
#        native-country  act
# 42093              38    0
# 31739              38    0
# 10773              38    0
# 15850              38    0
# 40645              38    1
# ...               ...  ...
# 34408              38    0
# 13238              38    0
# 31432               7    0
# 19093              38    0
# 36935              38    0
#
# [22611 rows x 14 columns]

# %%
X_test_res['pred'] = X_test.apply(lambda x: clf.predict([x.to_list()]), axis=1)

# %%
mis_class=X_test_res.loc[X_test_res['act']!=X_test_res['pred']]

# %%
mis_class.describe()
# Out:
#                age    workclass    education  educational-num  marital-status  \
# count  4340.000000  4340.000000  4340.000000      4340.000000     4340.000000
# mean     43.093088     2.245161    10.697926        10.786175        2.127189
# std      11.101165     1.068214     3.183306         2.404362        1.074950
# min      18.000000     0.000000     0.000000         1.000000        0.000000
# 25%      35.000000     2.000000     9.000000         9.000000        2.000000
# 50%      42.000000     2.000000    11.000000        10.000000        2.000000
# 75%      51.000000     2.000000    12.000000        13.000000        2.000000
# max      90.000000     6.000000    15.000000        16.000000        6.000000
#
#         occupation  relationship         race       gender  capital-gain  \
# count  4340.000000   4340.000000  4340.000000  4340.000000   4340.000000
# mean      6.293779      0.842857     3.736636     0.812903    205.405069
# std       4.147445      1.588507     0.785613     0.390034   2076.692283
# min       0.000000      0.000000     0.000000     0.000000      0.000000
# 25%       3.000000      0.000000     4.000000     1.000000      0.000000
# 50%       6.000000      0.000000     4.000000     1.000000      0.000000
# 75%      10.000000      1.000000     4.000000     1.000000      0.000000
# max      13.000000      5.000000     4.000000     1.000000  99999.000000
#
#        capital-loss  hours-per-week  native-country          act
# count   4340.000000     4340.000000     4340.000000  4340.000000
# mean      52.154147       44.446083       36.249309     0.496774
# std      310.142974       11.730440        6.520064     0.500047
# min        0.000000        2.000000        0.000000     0.000000
# 25%        0.000000       40.000000       38.000000     0.000000
# 50%        0.000000       40.000000       38.000000     0.000000
# 75%        0.000000       50.000000       38.000000     1.000000
# max     3175.000000       99.000000       39.000000     1.000000

# %%
# mis-classified data
mis_class.to_csv(r"../../InputData/AdultDataset/ForClassification/CleanAdult_numerical_mis.csv", index=False)

# %% [markdown]
# ## show case of a group

# %%
X_test_min = X_test[(X_test['workclass'] == 2) & 
                    (X_test['race'] == 4) & 
                    (X_test['gender'] == 1)& 
                    (X_test['educational-num'] == 9)& 
                    (X_test['native-country'] == 38)]

# %%
mis_class_min = mis_class[(mis_class['workclass'] == 2) & 
                          (mis_class['race'] == 4) & 
                          (mis_class['gender'] == 1) &  
                          (mis_class['educational-num'] == 9)& 
                          (mis_class['native-country'] == 38)]

# %%
len(mis_class_min)
# Out:
# 632

# %%
X_test_min
# Out:
#        age  workclass  education  educational-num  marital-status  occupation  \
# 16139   41          2         11                9               2          11
# 34252   34          2         11                9               0          11
# 30482   30          2         11                9               0          11
# 9231    34          2         11                9               2           2
# 40753   40          2         11                9               2          11
# ...    ...        ...        ...              ...             ...         ...
# 43111   53          2         11                9               2           3
# 42923   36          2         11                9               2           3
# 30778   24          2         11                9               4           3
# 47207   56          2         11                9               2           5
# 34408   36          2         11                9               0           6
#
#        relationship  race  gender  capital-gain  capital-loss  hours-per-week  \
# 16139             0     4       1             0             0              62
# 34252             1     4       1             0          1669              45
# 30482             4     4       1          1151             0              30
# 9231              0     4       1             0             0              50
# 40753             0     4       1             0             0              40
# ...             ...   ...     ...           ...           ...             ...
# 43111             0     4       1             0             0              40
# 42923             0     4       1             0             0              40
# 30778             4     4       1             0             0              40
# 47207             0     4       1             0             0              18
# 34408             4     4       1             0             0              40
#
#        native-country
# 16139              38
# 34252              38
# 30482              38
# 9231               38
# 40753              38
# ...               ...
# 43111              38
# 42923              38
# 30778              38
# 47207              38
# 34408              38
#
# [3159 rows x 13 columns]

# %%
len(mis_class)
# Out:
# 4298

# %%
acc = (1-len(mis_class)/len(X_test))*100

# %%
acc
# Out:
# 80.99155278404317

# %%
X_test_min
# Out:
#        age  workclass  education  educational-num  marital-status  occupation  \
# 16139   41          2         11                9               2          11
# 34252   34          2         11                9               0          11
# 30482   30          2         11                9               0          11
# 9231    34          2         11                9               2           2
# 40753   40          2         11                9               2          11
# ...    ...        ...        ...              ...             ...         ...
# 43111   53          2         11                9               2           3
# 42923   36          2         11                9               2           3
# 30778   24          2         11                9               4           3
# 47207   56          2         11                9               2           5
# 34408   36          2         11                9               0           6
#
#        relationship  race  gender  capital-gain  capital-loss  hours-per-week  \
# 16139             0     4       1             0             0              62
# 34252             1     4       1             0          1669              45
# 30482             4     4       1          1151             0              30
# 9231              0     4       1             0             0              50
# 40753             0     4       1             0             0              40
# ...             ...   ...     ...           ...           ...             ...
# 43111             0     4       1             0             0              40
# 42923             0     4       1             0             0              40
# 30778             4     4       1             0             0              40
# 47207             0     4       1             0             0              18
# 34408             4     4       1             0             0              40
#
#        native-country
# 16139              38
# 34252              38
# 30482              38
# 9231               38
# 40753              38
# ...               ...
# 43111              38
# 42923              38
# 30778              38
# 47207              38
# 34408              38
#
# [3159 rows x 13 columns]

# %%
X_test_res_min =  X_test_res[(X_test_res['workclass'] == 2) & 
                          (X_test_res['race'] == 4) & 
                          (X_test_res['gender'] == 1)]

# %%
X_test_res_min_mis_class = X_test_res_min.loc[X_test_res_min['act']!=X_test_res_min['pred']]

# %%
X_test_res_min_mis_class
# Out:
#        age  workclass  education  educational-num  marital-status  occupation  \
# 9231    34          2         11                9               2           2
# 42467   33          2         12               14               2           9
# 40753   40          2         11                9               2          11
# 37051   33          2         11                9               2          11
# 46327   29          2          9               13               2          11
# ...    ...        ...        ...              ...             ...         ...
# 17586   37          2          9               13               2           6
# 461     36          2         11                9               2           2
# 42946   66          2         15               10               2          13
# 1014    48          2         11                9               2           6
# 18325   53          2          9               13               0           3
#
#        relationship  race  gender  capital-gain  capital-loss  hours-per-week  \
# 9231              0     4       1             0             0              50
# 42467             0     4       1             0             0              45
# 40753             0     4       1             0             0              40
# 37051             0     4       1             0          1672              55
# 46327             0     4       1             0             0              40
# ...             ...   ...     ...           ...           ...             ...
# 17586             0     4       1             0             0              43
# 461               0     4       1             0             0              40
# 42946             0     4       1             0          1258              20
# 1014              0     4       1             0             0              40
# 18325             1     4       1             0             0              70
#
#        native-country  act pred
# 9231               38    1  [0]
# 42467              38    1  [0]
# 40753              38    1  [0]
# 37051              38    0  [1]
# 46327              38    0  [1]
# ...               ...  ...  ...
# 17586              38    1  [0]
# 461                32    0  [1]
# 42946              38    0  [1]
# 1014                5    0  [1]
# 18325              38    0  [1]
#
# [2079 rows x 15 columns]

# %%
min_acc = (1 - len(mis_class_min)/len(X_test_min))*100

# %%
min_acc
# Out:
# 79.99366888255777

# %% [markdown]
# ## COMPAS

# %%
compas_data = pd.read_csv("RecidivismData_Original-categorized.csv")
compas_data.head(10)
# Out:
#                  name FirstName     LastName   sex DateOfBirth  age  \
# 0    miguel hernandez    miguel    hernandez  Male   4/18/1947   69
# 1         kevon dixon     kevon        dixon  Male   1/22/1982   34
# 2            ed philo        ed        philo  Male   5/14/1991   24
# 3         marcu brown     marcu        brown  Male   1/21/1993   23
# 4  bouthy pierrelouis    bouthy  pierrelouis  Male   1/22/1973   43
# 5        marsha miles    marsha        miles  Male   8/22/1971   44
# 6       edward riddle    edward       riddle  Male   7/23/1974   41
# 7      steven stewart    steven      stewart  Male   2/25/1973   43
# 8           bo bradac        bo       bradac  Male   6/10/1994   21
# 9      benjamin franc  benjamin        franc  Male    6/1/1988   27
#
#                race  juv_fel_count  decile_score  juv_misd_count  ...   end  \
# 0             Other              0             1               0  ...   327
# 1  African-American              0             3               0  ...   159
# 2  African-American              0             4               0  ...    63
# 3  African-American              0             8               1  ...  1174
# 4             Other              0             1               0  ...  1102
# 5             Other              0             1               0  ...   853
# 6         Caucasian              0             6               0  ...    40
# 7             Other              0             4               0  ...   265
# 8         Caucasian              0             3               0  ...   428
# 9         Caucasian              0             4               0  ...   857
#
#    event  two_year_recid  Violence_score Recidivism_score  MarriageStatus  \
# 0      0               0           -4.31            -2.78          Single
# 1      1               1           -3.07            -0.76          Single
# 2      0               1           -1.31             0.44          Single
# 3      0               0           -1.59             0.16          Single
# 4      0               0           -3.23            -2.20         Married
# 5      0               0           -3.30            -1.93       Separated
# 6      1               1           -2.89            -0.16          Single
# 7      0               0           -2.44            -0.72         Married
# 8      1               1           -1.84            -0.79          Single
# 9      0               0           -2.12            -0.69          Single
#
#    sexC  ageC  raceC  MC
# 0     0     3      3   0
# 1     0     1      0   0
# 2     0     1      0   0
# 3     0     1      0   0
# 4     0     2      3   1
# 5     0     2      3   2
# 6     0     2      1   0
# 7     0     2      3   1
# 8     0     1      1   0
# 9     0     1      1   0
#
# [10 rows x 30 columns]

# %%
compas_data.shape
# Out:
# (6889, 30)

# %%
compas_data.columns
# Out:
# Index(['name', 'FirstName', 'LastName', 'sex', 'DateOfBirth', 'age', 'race',
#        'juv_fel_count', 'decile_score', 'juv_misd_count', 'juv_other_count',
#        'priors_count', 'days_b_screening_arrest', 'c_days_from_compas',
#        'c_charge_degree', 'is_recid', 'is_violent_recid', 'v_decile_score',
#        'priors_count_C', 'start', 'end', 'event', 'two_year_recid',
#        'Violence_score', 'Recidivism_score', 'MarriageStatus', 'sexC', 'ageC',
#        'raceC', 'MC'],
#       dtype='object')

# %%
compas_data['c_days_from_compas'].value_counts()
# Out:
# 1.0       4248
# 0.0        857
# 2.0        206
# 3.0         91
# 4.0         78
#           ...
# 4696.0       1
# 1423.0       1
# 2994.0       1
# 389.0        1
# 3279.0       1
# Name: c_days_from_compas, Length: 486, dtype: int64

# %%
features = ['sexC', 'ageC','raceC', 'MC','priors_count_C','is_violent_recid', 'v_decile_score', 'Violence_score']
X = compas_data[features].copy()
y = compas_data['is_recid'].copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=1)

# %%
X_test
# Out:
#       sexC  ageC  raceC  MC  priors_count_C  is_violent_recid  v_decile_score  \
# 1457     0     1      0   0               4                 1               5
# 1380     1     1      0   0               3                 0               3
# 2975     0     1      0   0              21                 0               9
# 6704     0     1      0   0               0                 0               5
# 4053     1     1      0   0               0                 1               4
# ...    ...   ...    ...  ..             ...               ...             ...
# 251      0     1      0   0               4                 0               4
# 3646     0     1      0   0              11                 0               5
# 5594     0     1      1   0               3                 0               5
# 1090     1     1      0   0              14                 0               8
# 2016     0     2      1   0               0                 0               1
#
#       Violence_score
# 1457           -1.22
# 1380           -2.26
# 2975           -2.03
# 6704           -1.96
# 4053           -2.02
# ...              ...
# 251            -2.18
# 3646           -1.74
# 5594           -1.82
# 1090           -1.07
# 2016           -3.63
#
# [3445 rows x 8 columns]

# %%
clf = DecisionTreeClassifier(max_depth=10)
clf = clf.fit(X_train, y_train)

# %%
num = 0
for index, row in X_test.iterrows():
    if clf.predict([row.to_list()]) != y_test.loc[index]:
        num = num + 1
        print ('-----------------')
        print (str(num) + '\n')
        print (row)
        
print(num)
print((1-num/len(X_test))*100)
# Out:
# -----------------
# 1
#
# sexC                1.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.26
# Name: 1380, dtype: float64
# -----------------
# 2
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.07
# Name: 2406, dtype: float64
# -----------------
# 3
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -2.82
# Name: 2478, dtype: float64
# -----------------
# 4
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      8.00
# Violence_score     -1.15
# Name: 2973, dtype: float64
# -----------------
# 5
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      7.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -2.95
# Name: 4712, dtype: float64
# -----------------
# 6
#
# sexC                1.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.74
# Name: 906, dtype: float64
# -----------------
# 7
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.52
# Name: 6263, dtype: float64
# -----------------
# 8
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.28
# Name: 2505, dtype: float64
# -----------------
# 9
#
# sexC                0.00
# ageC                1.00
# raceC               2.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.52
# Name: 1502, dtype: float64
# -----------------
# 10
#
# sexC                1.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.88
# Name: 5577, dtype: float64
# -----------------
# 11
#
# sexC                1.00
# ageC                2.00
# raceC               3.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.76
# Name: 4570, dtype: float64
# -----------------
# 12
#
# sexC                0.0
# ageC                1.0
# raceC               1.0
# MC                  0.0
# priors_count_C      1.0
# is_violent_recid    0.0
# v_decile_score      8.0
# Violence_score     -1.1
# Name: 2912, dtype: float64
# -----------------
# 13
#
# sexC                1.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      4.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.03
# Name: 3417, dtype: float64
# -----------------
# 14
#
# sexC                 0.00
# ageC                 2.00
# raceC                0.00
# MC                   0.00
# priors_count_C      18.00
# is_violent_recid     0.00
# v_decile_score       8.00
# Violence_score      -1.11
# Name: 2361, dtype: float64
# -----------------
# 15
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      7.00
# Violence_score     -1.33
# Name: 1731, dtype: float64
# -----------------
# 16
#
# sexC                0.00
# ageC                1.00
# raceC               2.00
# MC                  1.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.45
# Name: 5821, dtype: float64
# -----------------
# 17
#
# sexC                0.00
# ageC                1.00
# raceC               3.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.79
# Name: 5214, dtype: float64
# -----------------
# 18
#
# sexC                 0.00
# ageC                 1.00
# raceC                0.00
# MC                   0.00
# priors_count_C      29.00
# is_violent_recid     0.00
# v_decile_score       8.00
# Violence_score      -1.23
# Name: 4545, dtype: float64
# -----------------
# 19
#
# sexC                1.00
# ageC                1.00
# raceC               1.00
# MC                  1.00
# priors_count_C      7.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.13
# Name: 6071, dtype: float64
# -----------------
# 20
#
# sexC                1.00
# ageC                2.00
# raceC               2.00
# MC                  1.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -4.13
# Name: 2692, dtype: float64
# -----------------
# 21
#
# sexC                 0.00
# ageC                 2.00
# raceC                2.00
# MC                   0.00
# priors_count_C      12.00
# is_violent_recid     0.00
# v_decile_score       3.00
# Violence_score      -2.51
# Name: 4872, dtype: float64
# -----------------
# 22
#
# sexC                0.00
# ageC                2.00
# raceC               3.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.56
# Name: 5538, dtype: float64
# -----------------
# 23
#
# sexC                0.00
# ageC                1.00
# raceC               3.00
# MC                  1.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.84
# Name: 4953, dtype: float64
# -----------------
# 24
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.92
# Name: 5988, dtype: float64
# -----------------
# 25
#
# sexC                1.00
# ageC                1.00
# raceC               2.00
# MC                  0.00
# priors_count_C      5.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.89
# Name: 1626, dtype: float64
# -----------------
# 26
#
# sexC                1.00
# ageC                0.00
# raceC               1.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.53
# Name: 5107, dtype: float64
# -----------------
# 27
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.45
# Name: 3715, dtype: float64
# -----------------
# 28
#
# sexC                0.00
# ageC                2.00
# raceC               2.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.67
# Name: 4358, dtype: float64
# -----------------
# 29
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.28
# Name: 2227, dtype: float64
# -----------------
# 30
#
# sexC                0.0
# ageC                1.0
# raceC               1.0
# MC                  0.0
# priors_count_C      3.0
# is_violent_recid    0.0
# v_decile_score      4.0
# Violence_score     -2.1
# Name: 4728, dtype: float64
# -----------------
# 31
#
# sexC                0.00
# ageC                3.00
# raceC               1.00
# MC                  1.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.73
# Name: 5090, dtype: float64
# -----------------
# 32
#
# sexC                1.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      7.00
# Violence_score     -1.47
# Name: 3761, dtype: float64
# -----------------
# 33
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.93
# Name: 4525, dtype: float64
# -----------------
# 34
#
# sexC                 0.00
# ageC                 2.00
# raceC                0.00
# MC                   0.00
# priors_count_C      19.00
# is_violent_recid     0.00
# v_decile_score       9.00
# Violence_score      -0.88
# Name: 4583, dtype: float64
# -----------------
# 35
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      6.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.51
# Name: 5406, dtype: float64
# -----------------
# 36
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.47
# Name: 4678, dtype: float64
# -----------------
# 37
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.05
# Name: 767, dtype: float64
# -----------------
# 38
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      6.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.46
# Name: 3982, dtype: float64
# -----------------
# 39
#
# sexC                 0.00
# ageC                 2.00
# raceC                1.00
# MC                   0.00
# priors_count_C      36.00
# is_violent_recid     0.00
# v_decile_score       9.00
# Violence_score      -0.93
# Name: 313, dtype: float64
# -----------------
# 40
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.32
# Name: 2358, dtype: float64
# -----------------
# 41
#
# sexC                1.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.78
# Name: 4668, dtype: float64
# -----------------
# 42
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.76
# Name: 3988, dtype: float64
# -----------------
# 43
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      4.00
# is_violent_recid    0.00
# v_decile_score      7.00
# Violence_score     -1.46
# Name: 3282, dtype: float64
# -----------------
# 44
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.59
# Name: 3513, dtype: float64
# -----------------
# 45
#
# sexC                 0.00
# ageC                 1.00
# raceC                1.00
# MC                   0.00
# priors_count_C      13.00
# is_violent_recid     0.00
# v_decile_score       3.00
# Violence_score      -2.32
# Name: 4247, dtype: float64
# -----------------
# 46
#
# sexC                 0.00
# ageC                 2.00
# raceC                0.00
# MC                   0.00
# priors_count_C      20.00
# is_violent_recid     0.00
# v_decile_score       4.00
# Violence_score      -2.11
# Name: 793, dtype: float64
# -----------------
# 47
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  4.00
# priors_count_C      7.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.25
# Name: 1971, dtype: float64
# -----------------
# 48
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  1.00
# priors_count_C      4.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.59
# Name: 2193, dtype: float64
# -----------------
# 49
#
# sexC                0.0
# ageC                1.0
# raceC               1.0
# MC                  0.0
# priors_count_C      2.0
# is_violent_recid    0.0
# v_decile_score      5.0
# Violence_score     -1.8
# Name: 3276, dtype: float64
# -----------------
# 50
#
# sexC                0.00
# ageC                1.00
# raceC               3.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.71
# Name: 325, dtype: float64
# -----------------
# 51
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  4.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.18
# Name: 2851, dtype: float64
# -----------------
# 52
#
# sexC                0.00
# ageC                2.00
# raceC               3.00
# MC                  1.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.74
# Name: 4867, dtype: float64
# -----------------
# 53
#
# sexC                 0.0
# ageC                 1.0
# raceC                1.0
# MC                   0.0
# priors_count_C      12.0
# is_violent_recid     0.0
# v_decile_score       2.0
# Violence_score      -2.9
# Name: 5461, dtype: float64
# -----------------
# 54
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.56
# Name: 4249, dtype: float64
# -----------------
# 55
#
# sexC                0.0
# ageC                1.0
# raceC               1.0
# MC                  1.0
# priors_count_C      2.0
# is_violent_recid    0.0
# v_decile_score      6.0
# Violence_score     -1.6
# Name: 3990, dtype: float64
# -----------------
# 56
#
# sexC                0.0
# ageC                1.0
# raceC               0.0
# MC                  0.0
# priors_count_C      0.0
# is_violent_recid    0.0
# v_decile_score      7.0
# Violence_score     -1.4
# Name: 5252, dtype: float64
# -----------------
# 57
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -2.82
# Name: 420, dtype: float64
# -----------------
# 58
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.58
# Name: 2377, dtype: float64
# -----------------
# 59
#
# sexC                0.00
# ageC                1.00
# raceC               3.00
# MC                  0.00
# priors_count_C      4.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.05
# Name: 2730, dtype: float64
# -----------------
# 60
#
# sexC                 0.00
# ageC                 1.00
# raceC                0.00
# MC                   0.00
# priors_count_C      12.00
# is_violent_recid     0.00
# v_decile_score       3.00
# Violence_score      -2.45
# Name: 6828, dtype: float64
# -----------------
# 61
#
# sexC                0.00
# ageC                2.00
# raceC               0.00
# MC                  1.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.91
# Name: 6163, dtype: float64
# -----------------
# 62
#
# sexC                0.00
# ageC                2.00
# raceC               0.00
# MC                  0.00
# priors_count_C      6.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.77
# Name: 4493, dtype: float64
# -----------------
# 63
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.52
# Name: 1160, dtype: float64
# -----------------
# 64
#
# sexC                1.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      9.00
# Violence_score     -0.91
# Name: 4464, dtype: float64
# -----------------
# 65
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.24
# Name: 1163, dtype: float64
# -----------------
# 66
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.31
# Name: 503, dtype: float64
# -----------------
# 67
#
# sexC                0.00
# ageC                1.00
# raceC               2.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      9.00
# Violence_score     -0.91
# Name: 1913, dtype: float64
# -----------------
# 68
#
# sexC                1.00
# ageC                1.00
# raceC               2.00
# MC                  1.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.63
# Name: 2015, dtype: float64
# -----------------
# 69
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  0.00
# priors_count_C      6.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.58
# Name: 3631, dtype: float64
# -----------------
# 70
#
# sexC                0.0
# ageC                1.0
# raceC               0.0
# MC                  0.0
# priors_count_C      6.0
# is_violent_recid    0.0
# v_decile_score      4.0
# Violence_score     -2.1
# Name: 1183, dtype: float64
# -----------------
# 71
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      4.00
# is_violent_recid    0.00
# v_decile_score      9.00
# Violence_score     -0.68
# Name: 3875, dtype: float64
# -----------------
# 72
#
# sexC                0.00
# ageC                3.00
# raceC               0.00
# MC                  5.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -4.31
# Name: 1079, dtype: float64
# -----------------
# 73
#
# sexC                0.0
# ageC                1.0
# raceC               1.0
# MC                  0.0
# priors_count_C      1.0
# is_violent_recid    0.0
# v_decile_score      4.0
# Violence_score     -2.2
# Name: 2181, dtype: float64
# -----------------
# 74
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.41
# Name: 5893, dtype: float64
# -----------------
# 75
#
# sexC                 0.00
# ageC                 2.00
# raceC                1.00
# MC                   0.00
# priors_count_C      16.00
# is_violent_recid     0.00
# v_decile_score       7.00
# Violence_score      -1.48
# Name: 6102, dtype: float64
# -----------------
# 76
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.56
# Name: 5392, dtype: float64
# -----------------
# 77
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.02
# Name: 1410, dtype: float64
# -----------------
# 78
#
# sexC                0.00
# ageC                2.00
# raceC               3.00
# MC                  0.00
# priors_count_C      6.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.37
# Name: 5208, dtype: float64
# -----------------
# 79
#
# sexC                0.00
# ageC                2.00
# raceC               3.00
# MC                  1.00
# priors_count_C      7.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.49
# Name: 2932, dtype: float64
# -----------------
# 80
#
# sexC                1.00
# ageC                1.00
# raceC               3.00
# MC                  4.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.96
# Name: 758, dtype: float64
# -----------------
# 81
#
# sexC                1.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.05
# Name: 1777, dtype: float64
# -----------------
# 82
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.94
# Name: 4894, dtype: float64
# -----------------
# 83
#
# sexC                1.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.42
# Name: 1794, dtype: float64
# -----------------
# 84
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      7.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.52
# Name: 3309, dtype: float64
# -----------------
# 85
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.17
# Name: 1217, dtype: float64
# -----------------
# 86
#
# sexC                 0.00
# ageC                 1.00
# raceC                0.00
# MC                   0.00
# priors_count_C       2.00
# is_violent_recid     0.00
# v_decile_score      10.00
# Violence_score       0.09
# Name: 4498, dtype: float64
# -----------------
# 87
#
# sexC                 0.00
# ageC                 2.00
# raceC                0.00
# MC                   0.00
# priors_count_C      13.00
# is_violent_recid     0.00
# v_decile_score       3.00
# Violence_score      -2.51
# Name: 6298, dtype: float64
# -----------------
# 88
#
# sexC                0.0
# ageC                2.0
# raceC               0.0
# MC                  0.0
# priors_count_C      2.0
# is_violent_recid    0.0
# v_decile_score      2.0
# Violence_score     -2.3
# Name: 871, dtype: float64
# -----------------
# 89
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.87
# Name: 5088, dtype: float64
# -----------------
# 90
#
# sexC                1.00
# ageC                2.00
# raceC               0.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.93
# Name: 6250, dtype: float64
# -----------------
# 91
#
# sexC                 0.00
# ageC                 2.00
# raceC                1.00
# MC                   0.00
# priors_count_C      15.00
# is_violent_recid     0.00
# v_decile_score       3.00
# Violence_score      -2.25
# Name: 1344, dtype: float64
# -----------------
# 92
#
# sexC                1.00
# ageC                3.00
# raceC               1.00
# MC                  1.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -4.36
# Name: 116, dtype: float64
# -----------------
# 93
#
# sexC                0.00
# ageC                2.00
# raceC               0.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.49
# Name: 2954, dtype: float64
# -----------------
# 94
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      8.00
# Violence_score     -1.12
# Name: 368, dtype: float64
# -----------------
# 95
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      4.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.74
# Name: 1102, dtype: float64
# -----------------
# 96
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.75
# Name: 3780, dtype: float64
# -----------------
# 97
#
# sexC                0.00
# ageC                2.00
# raceC               0.00
# MC                  0.00
# priors_count_C      8.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -1.66
# Name: 2320, dtype: float64
# -----------------
# 98
#
# sexC                1.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      8.00
# Violence_score     -1.21
# Name: 4555, dtype: float64
# -----------------
# 99
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.74
# Name: 1628, dtype: float64
# -----------------
# 100
#
# sexC                 0.00
# ageC                 1.00
# raceC                0.00
# MC                   0.00
# priors_count_C       6.00
# is_violent_recid     0.00
# v_decile_score      10.00
# Violence_score      -0.55
# Name: 6044, dtype: float64
# -----------------
# 101
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      7.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.53
# Name: 308, dtype: float64
# -----------------
# 102
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      5.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.64
# Name: 1528, dtype: float64
# -----------------
# 103
#
# sexC                1.00
# ageC                1.00
# raceC               1.00
# MC                  2.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.67
# Name: 6301, dtype: float64
# -----------------
# 104
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.74
# Name: 3636, dtype: float64
# -----------------
# 105
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  6.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.38
# Name: 5258, dtype: float64
# -----------------
# 106
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      5.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.78
# Name: 1773, dtype: float64
# -----------------
# 107
#
# sexC                0.00
# ageC                1.00
# raceC               2.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.18
# Name: 3207, dtype: float64
# -----------------
# 108
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.48
# Name: 6504, dtype: float64
# -----------------
# 109
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  0.00
# priors_count_C      5.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.85
# Name: 2328, dtype: float64
# -----------------
# 110
#
# sexC                 0.00
# ageC                 1.00
# raceC                0.00
# MC                   0.00
# priors_count_C      16.00
# is_violent_recid     0.00
# v_decile_score       3.00
# Violence_score      -2.31
# Name: 975, dtype: float64
# -----------------
# 111
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.83
# Name: 354, dtype: float64
# -----------------
# 112
#
# sexC                 0.00
# ageC                 2.00
# raceC                0.00
# MC                   1.00
# priors_count_C      15.00
# is_violent_recid     0.00
# v_decile_score       2.00
# Violence_score      -2.68
# Name: 4040, dtype: float64
# -----------------
# 113
#
# sexC                0.00
# ageC                3.00
# raceC               0.00
# MC                  0.00
# priors_count_C      9.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.93
# Name: 5173, dtype: float64
# -----------------
# 114
#
# sexC                1.00
# ageC                3.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.23
# Name: 2967, dtype: float64
# -----------------
# 115
#
# sexC                0.00
# ageC                1.00
# raceC               3.00
# MC                  2.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.22
# Name: 3108, dtype: float64
# -----------------
# 116
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      6.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.06
# Name: 1740, dtype: float64
# -----------------
# 117
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      7.00
# Violence_score     -1.56
# Name: 6090, dtype: float64
# -----------------
# 118
#
# sexC                0.0
# ageC                1.0
# raceC               0.0
# MC                  0.0
# priors_count_C      0.0
# is_violent_recid    0.0
# v_decile_score      4.0
# Violence_score     -2.2
# Name: 1064, dtype: float64
# -----------------
# 119
#
# sexC                0.00
# ageC                0.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.72
# Name: 4836, dtype: float64
# -----------------
# 120
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.09
# Name: 4575, dtype: float64
# -----------------
# 121
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  5.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -4.08
# Name: 5316, dtype: float64
# -----------------
# 122
#
# sexC                0.00
# ageC                1.00
# raceC               2.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      7.00
# Violence_score     -1.29
# Name: 3936, dtype: float64
# -----------------
# 123
#
# sexC                0.00
# ageC                2.00
# raceC               0.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -2.98
# Name: 3400, dtype: float64
# -----------------
# 124
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      7.00
# Violence_score     -1.34
# Name: 3376, dtype: float64
# -----------------
# 125
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      8.00
# Violence_score     -1.25
# Name: 2812, dtype: float64
# -----------------
# 126
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      8.00
# Violence_score     -1.22
# Name: 5301, dtype: float64
# -----------------
# 127
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  0.00
# priors_count_C      5.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.17
# Name: 3777, dtype: float64
# -----------------
# 128
#
# sexC                0.00
# ageC                2.00
# raceC               0.00
# MC                  1.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.02
# Name: 901, dtype: float64
# -----------------
# 129
#
# sexC                1.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.68
# Name: 4146, dtype: float64
# -----------------
# 130
#
# sexC                0.00
# ageC                2.00
# raceC               2.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.54
# Name: 2213, dtype: float64
# -----------------
# 131
#
# sexC                0.0
# ageC                1.0
# raceC               2.0
# MC                  0.0
# priors_count_C      0.0
# is_violent_recid    0.0
# v_decile_score      4.0
# Violence_score     -2.0
# Name: 2661, dtype: float64
# -----------------
# 132
#
# sexC                1.00
# ageC                1.00
# raceC               1.00
# MC                  5.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.15
# Name: 1508, dtype: float64
# -----------------
# 133
#
# sexC                0.00
# ageC                2.00
# raceC               0.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.72
# Name: 6643, dtype: float64
# -----------------
# 134
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      8.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.68
# Name: 4993, dtype: float64
# -----------------
# 135
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.85
# Name: 784, dtype: float64
# -----------------
# 136
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      7.00
# Violence_score     -1.44
# Name: 6846, dtype: float64
# -----------------
# 137
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.63
# Name: 3738, dtype: float64
# -----------------
# 138
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.54
# Name: 654, dtype: float64
# -----------------
# 139
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      9.00
# Violence_score     -0.96
# Name: 1355, dtype: float64
# -----------------
# 140
#
# sexC                1.00
# ageC                1.00
# raceC               1.00
# MC                  5.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.02
# Name: 2899, dtype: float64
# -----------------
# 141
#
# sexC                0.00
# ageC                1.00
# raceC               3.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.24
# Name: 5912, dtype: float64
# -----------------
# 142
#
# sexC                 0.00
# ageC                 2.00
# raceC                0.00
# MC                   0.00
# priors_count_C      15.00
# is_violent_recid     0.00
# v_decile_score       2.00
# Violence_score      -2.86
# Name: 2809, dtype: float64
# -----------------
# 143
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.64
# Name: 623, dtype: float64
# -----------------
# 144
#
# sexC                0.0
# ageC                1.0
# raceC               1.0
# MC                  0.0
# priors_count_C      0.0
# is_violent_recid    0.0
# v_decile_score      1.0
# Violence_score     -3.0
# Name: 4092, dtype: float64
# -----------------
# 145
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.72
# Name: 6176, dtype: float64
# -----------------
# 146
#
# sexC                 0.00
# ageC                 1.00
# raceC                0.00
# MC                   0.00
# priors_count_C      20.00
# is_violent_recid     0.00
# v_decile_score       5.00
# Violence_score      -1.89
# Name: 5758, dtype: float64
# -----------------
# 147
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.25
# Name: 3505, dtype: float64
# -----------------
# 148
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.74
# Name: 6308, dtype: float64
# -----------------
# 149
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  4.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -2.98
# Name: 4165, dtype: float64
# -----------------
# 150
#
# sexC                0.00
# ageC                2.00
# raceC               0.00
# MC                  5.00
# priors_count_C      5.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.17
# Name: 4104, dtype: float64
# -----------------
# 151
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      7.00
# Violence_score     -1.32
# Name: 3463, dtype: float64
# -----------------
# 152
#
# sexC                1.00
# ageC                0.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.65
# Name: 1519, dtype: float64
# -----------------
# 153
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  1.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.13
# Name: 2617, dtype: float64
# -----------------
# 154
#
# sexC                 0.00
# ageC                 1.00
# raceC                0.00
# MC                   0.00
# priors_count_C      15.00
# is_violent_recid     0.00
# v_decile_score       6.00
# Violence_score      -1.59
# Name: 3001, dtype: float64
# -----------------
# 155
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      9.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.37
# Name: 2632, dtype: float64
# -----------------
# 156
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.88
# Name: 6636, dtype: float64
# -----------------
# 157
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.98
# Name: 1309, dtype: float64
# -----------------
# 158
#
# sexC                0.00
# ageC                3.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -4.01
# Name: 553, dtype: float64
# -----------------
# 159
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  1.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.92
# Name: 4853, dtype: float64
# -----------------
# 160
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.05
# Name: 1271, dtype: float64
# -----------------
# 161
#
# sexC                0.00
# ageC                1.00
# raceC               2.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.21
# Name: 2473, dtype: float64
# -----------------
# 162
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.74
# Name: 1216, dtype: float64
# -----------------
# 163
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      6.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.86
# Name: 2019, dtype: float64
# -----------------
# 164
#
# sexC                0.00
# ageC                2.00
# raceC               0.00
# MC                  0.00
# priors_count_C      9.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.81
# Name: 3579, dtype: float64
# -----------------
# 165
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  1.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -2.99
# Name: 6317, dtype: float64
# -----------------
# 166
#
# sexC                1.00
# ageC                1.00
# raceC               1.00
# MC                  1.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.66
# Name: 607, dtype: float64
# -----------------
# 167
#
# sexC                1.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      8.00
# Violence_score     -1.25
# Name: 394, dtype: float64
# -----------------
# 168
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.93
# Name: 4013, dtype: float64
# -----------------
# 169
#
# sexC                0.00
# ageC                1.00
# raceC               2.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.64
# Name: 1958, dtype: float64
# -----------------
# 170
#
# sexC                0.0
# ageC                1.0
# raceC               1.0
# MC                  0.0
# priors_count_C      4.0
# is_violent_recid    0.0
# v_decile_score      2.0
# Violence_score     -2.7
# Name: 58, dtype: float64
# -----------------
# 171
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      7.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.51
# Name: 5155, dtype: float64
# -----------------
# 172
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.53
# Name: 4089, dtype: float64
# -----------------
# 173
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  5.00
# priors_count_C      4.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.84
# Name: 6829, dtype: float64
# -----------------
# 174
#
# sexC                1.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -1.98
# Name: 4215, dtype: float64
# -----------------
# 175
#
# sexC                1.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.86
# Name: 634, dtype: float64
# -----------------
# 176
#
# sexC                0.00
# ageC                1.00
# raceC               3.00
# MC                  4.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.04
# Name: 3903, dtype: float64
# -----------------
# 177
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  2.00
# priors_count_C      6.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.05
# Name: 6363, dtype: float64
# -----------------
# 178
#
# sexC                0.00
# ageC                1.00
# raceC               3.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.12
# Name: 729, dtype: float64
# -----------------
# 179
#
# sexC                0.00
# ageC                1.00
# raceC               2.00
# MC                  1.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.84
# Name: 5944, dtype: float64
# -----------------
# 180
#
# sexC                1.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.86
# Name: 2351, dtype: float64
# -----------------
# 181
#
# sexC                1.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.82
# Name: 2012, dtype: float64
# -----------------
# 182
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  0.00
# priors_count_C      7.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.58
# Name: 5894, dtype: float64
# -----------------
# 183
#
# sexC                 0.00
# ageC                 1.00
# raceC                0.00
# MC                   0.00
# priors_count_C      14.00
# is_violent_recid     0.00
# v_decile_score       8.00
# Violence_score      -1.06
# Name: 229, dtype: float64
# -----------------
# 184
#
# sexC                0.0
# ageC                1.0
# raceC               0.0
# MC                  0.0
# priors_count_C      0.0
# is_violent_recid    0.0
# v_decile_score      7.0
# Violence_score     -1.4
# Name: 6845, dtype: float64
# -----------------
# 185
#
# sexC                0.0
# ageC                1.0
# raceC               0.0
# MC                  0.0
# priors_count_C      1.0
# is_violent_recid    0.0
# v_decile_score      4.0
# Violence_score     -2.0
# Name: 6446, dtype: float64
# -----------------
# 186
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.17
# Name: 863, dtype: float64
# -----------------
# 187
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.34
# Name: 994, dtype: float64
# -----------------
# 188
#
# sexC                0.00
# ageC                1.00
# raceC               2.00
# MC                  1.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.98
# Name: 4784, dtype: float64
# -----------------
# 189
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  1.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.52
# Name: 4709, dtype: float64
# -----------------
# 190
#
# sexC                 0.00
# ageC                 1.00
# raceC                1.00
# MC                   0.00
# priors_count_C      10.00
# is_violent_recid     0.00
# v_decile_score       3.00
# Violence_score      -2.33
# Name: 3123, dtype: float64
# -----------------
# 191
#
# sexC                 0.00
# ageC                 1.00
# raceC                0.00
# MC                   0.00
# priors_count_C       0.00
# is_violent_recid     0.00
# v_decile_score      10.00
# Violence_score      -0.42
# Name: 6582, dtype: float64
# -----------------
# 192
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      7.00
# Violence_score     -1.46
# Name: 3489, dtype: float64
# -----------------
# 193
#
# sexC                1.00
# ageC                1.00
# ...
# raceC               1.00
# MC                  5.00
# priors_count_C      7.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -4.11
# Name: 201, dtype: float64
# -----------------
# 987
#
# sexC                1.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.47
# Name: 2070, dtype: float64
# -----------------
# 988
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.33
# Name: 1986, dtype: float64
# -----------------
# 989
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -1.98
# Name: 3644, dtype: float64
# -----------------
# 990
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  1.00
# priors_count_C      6.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.78
# Name: 5287, dtype: float64
# -----------------
# 991
#
# sexC                1.00
# ageC                2.00
# raceC               0.00
# MC                  0.00
# priors_count_C      8.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.73
# Name: 6602, dtype: float64
# -----------------
# 992
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.35
# Name: 4571, dtype: float64
# -----------------
# 993
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      6.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.44
# Name: 3147, dtype: float64
# -----------------
# 994
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      5.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.51
# Name: 4136, dtype: float64
# -----------------
# 995
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      4.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.61
# Name: 6691, dtype: float64
# -----------------
# 996
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  2.00
# priors_count_C      8.00
# is_violent_recid    0.00
# v_decile_score      8.00
# Violence_score     -1.05
# Name: 3277, dtype: float64
# -----------------
# 997
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.16
# Name: 5968, dtype: float64
# -----------------
# 998
#
# sexC                0.0
# ageC                1.0
# raceC               0.0
# MC                  0.0
# priors_count_C      0.0
# is_violent_recid    0.0
# v_decile_score      5.0
# Violence_score     -1.9
# Name: 4732, dtype: float64
# -----------------
# 999
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      5.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.24
# Name: 733, dtype: float64
# -----------------
# 1000
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.56
# Name: 2474, dtype: float64
# -----------------
# 1001
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  1.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.29
# Name: 130, dtype: float64
# -----------------
# 1002
#
# sexC                0.0
# ageC                1.0
# raceC               0.0
# MC                  0.0
# priors_count_C      1.0
# is_violent_recid    0.0
# v_decile_score      6.0
# Violence_score     -1.6
# Name: 2950, dtype: float64
# -----------------
# 1003
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      5.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.78
# Name: 5640, dtype: float64
# -----------------
# 1004
#
# sexC                 0.0
# ageC                 1.0
# raceC                0.0
# MC                   0.0
# priors_count_C      21.0
# is_violent_recid     0.0
# v_decile_score       3.0
# Violence_score      -2.3
# Name: 5645, dtype: float64
# -----------------
# 1005
#
# sexC                 0.00
# ageC                 1.00
# raceC                0.00
# MC                   0.00
# priors_count_C      10.00
# is_violent_recid     0.00
# v_decile_score       8.00
# Violence_score      -1.22
# Name: 1635, dtype: float64
# -----------------
# 1006
#
# sexC                0.0
# ageC                2.0
# raceC               1.0
# MC                  1.0
# priors_count_C      1.0
# is_violent_recid    0.0
# v_decile_score      1.0
# Violence_score     -3.9
# Name: 1992, dtype: float64
# -----------------
# 1007
#
# sexC                0.00
# ageC                1.00
# raceC               2.00
# MC                  1.00
# priors_count_C      6.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.77
# Name: 3075, dtype: float64
# -----------------
# 1008
#
# sexC                 1.00
# ageC                 1.00
# raceC                1.00
# MC                   0.00
# priors_count_C      14.00
# is_violent_recid     0.00
# v_decile_score       5.00
# Violence_score      -1.78
# Name: 5146, dtype: float64
# -----------------
# 1009
#
# sexC                1.00
# ageC                2.00
# raceC               1.00
# MC                  1.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.62
# Name: 3833, dtype: float64
# -----------------
# 1010
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      5.00
# is_violent_recid    0.00
# v_decile_score      9.00
# Violence_score     -0.91
# Name: 5723, dtype: float64
# -----------------
# 1011
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      8.00
# Violence_score     -1.06
# Name: 1401, dtype: float64
# -----------------
# 1012
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  5.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.98
# Name: 4157, dtype: float64
# -----------------
# 1013
#
# sexC                0.00
# ageC                2.00
# raceC               0.00
# MC                  0.00
# priors_count_C      6.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.33
# Name: 3211, dtype: float64
# -----------------
# 1014
#
# sexC                1.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      7.00
# Violence_score     -1.26
# Name: 5408, dtype: float64
# -----------------
# 1015
#
# sexC                 0.00
# ageC                 1.00
# raceC                0.00
# MC                   0.00
# priors_count_C       3.00
# is_violent_recid     0.00
# v_decile_score      10.00
# Violence_score      -0.39
# Name: 2515, dtype: float64
# -----------------
# 1016
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.94
# Name: 2535, dtype: float64
# -----------------
# 1017
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.32
# Name: 435, dtype: float64
# -----------------
# 1018
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      5.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.24
# Name: 4862, dtype: float64
# -----------------
# 1019
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.84
# Name: 1770, dtype: float64
# -----------------
# 1020
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.04
# Name: 4893, dtype: float64
# -----------------
# 1021
#
# sexC                1.00
# ageC                2.00
# raceC               2.00
# MC                  0.00
# priors_count_C      9.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.54
# Name: 1664, dtype: float64
# -----------------
# 1022
#
# sexC                1.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.26
# Name: 1334, dtype: float64
# -----------------
# 1023
#
# sexC                1.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.11
# Name: 26, dtype: float64
# -----------------
# 1024
#
# sexC                1.0
# ageC                1.0
# raceC               0.0
# MC                  0.0
# priors_count_C      3.0
# is_violent_recid    0.0
# v_decile_score      3.0
# Violence_score     -2.4
# Name: 3051, dtype: float64
# -----------------
# 1025
#
# sexC                0.00
# ageC                2.00
# raceC               0.00
# MC                  1.00
# priors_count_C      6.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.44
# Name: 525, dtype: float64
# -----------------
# 1026
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      5.00
# is_violent_recid    0.00
# v_decile_score      9.00
# Violence_score     -0.98
# Name: 3301, dtype: float64
# -----------------
# 1027
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  5.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.37
# Name: 5896, dtype: float64
# -----------------
# 1028
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      7.00
# Violence_score     -1.29
# Name: 2369, dtype: float64
# -----------------
# 1029
#
# sexC                0.00
# ageC                2.00
# raceC               1.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.09
# Name: 5685, dtype: float64
# -----------------
# 1030
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      9.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.72
# Name: 3229, dtype: float64
# -----------------
# 1031
#
# sexC                0.0
# ageC                1.0
# raceC               0.0
# MC                  0.0
# priors_count_C      2.0
# is_violent_recid    0.0
# v_decile_score      3.0
# Violence_score     -2.4
# Name: 4527, dtype: float64
# -----------------
# 1032
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      4.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.07
# Name: 2456, dtype: float64
# -----------------
# 1033
#
# sexC                0.00
# ageC                0.00
# raceC               0.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.92
# Name: 1221, dtype: float64
# -----------------
# 1034
#
# sexC                0.0
# ageC                3.0
# raceC               0.0
# MC                  5.0
# priors_count_C      4.0
# is_violent_recid    0.0
# v_decile_score      3.0
# Violence_score     -2.5
# Name: 6848, dtype: float64
# -----------------
# 1035
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.52
# Name: 3872, dtype: float64
# -----------------
# 1036
#
# sexC                0.00
# ageC                1.00
# raceC               3.00
# MC                  0.00
# priors_count_C      5.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.93
# Name: 5182, dtype: float64
# -----------------
# 1037
#
# sexC                0.00
# ageC                2.00
# raceC               2.00
# MC                  5.00
# priors_count_C      4.00
# is_violent_recid    0.00
# v_decile_score      5.00
# Violence_score     -1.79
# Name: 1415, dtype: float64
# -----------------
# 1038
#
# sexC                0.00
# ageC                1.00
# raceC               3.00
# MC                  1.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.11
# Name: 739, dtype: float64
# -----------------
# 1039
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.02
# Name: 228, dtype: float64
# -----------------
# 1040
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      9.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.15
# Name: 3379, dtype: float64
# -----------------
# 1041
#
# sexC                0.00
# ageC                1.00
# raceC               2.00
# MC                  1.00
# priors_count_C      9.00
# is_violent_recid    0.00
# v_decile_score      7.00
# Violence_score     -1.37
# Name: 5476, dtype: float64
# -----------------
# 1042
#
# sexC                 1.00
# ageC                 1.00
# raceC                0.00
# MC                   0.00
# priors_count_C      14.00
# is_violent_recid     0.00
# v_decile_score       8.00
# Violence_score      -1.14
# Name: 2365, dtype: float64
# -----------------
# 1043
#
# sexC                1.00
# ageC                2.00
# raceC               0.00
# MC                  0.00
# priors_count_C      4.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.15
# Name: 1932, dtype: float64
# -----------------
# 1044
#
# sexC                 0.00
# ageC                 1.00
# raceC                0.00
# MC                   0.00
# priors_count_C      12.00
# is_violent_recid     0.00
# v_decile_score       5.00
# Violence_score      -1.96
# Name: 4044, dtype: float64
# -----------------
# 1045
#
# sexC                0.0
# ageC                3.0
# raceC               1.0
# MC                  0.0
# priors_count_C      6.0
# is_violent_recid    0.0
# v_decile_score      1.0
# Violence_score     -3.0
# Name: 1717, dtype: float64
# -----------------
# 1046
#
# sexC                0.00
# ageC                1.00
# raceC               1.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.41
# Name: 5419, dtype: float64
# -----------------
# 1047
#
# sexC                1.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.93
# Name: 138, dtype: float64
# -----------------
# 1048
#
# sexC                0.00
# ageC                1.00
# raceC               0.00
# MC                  0.00
# priors_count_C      4.00
# is_violent_recid    0.00
# v_decile_score      4.00
# Violence_score     -2.18
# Name: 251, dtype: float64
# -----------------
# 1049
#
# sexC                 1.00
# ageC                 1.00
# raceC                0.00
# MC                   0.00
# priors_count_C      14.00
# is_violent_recid     0.00
# v_decile_score       8.00
# Violence_score      -1.07
# Name: 1090, dtype: float64
# 1049
# 69.5500725689405

# %%
X_test
# Out:
#       sexC  ageC  raceC  MC  priors_count_C  is_violent_recid  v_decile_score  \
# 1457     0     1      0   0               4                 1               5
# 1380     1     1      0   0               3                 0               3
# 2975     0     1      0   0              21                 0               9
# 6704     0     1      0   0               0                 0               5
# 4053     1     1      0   0               0                 1               4
# ...    ...   ...    ...  ..             ...               ...             ...
# 251      0     1      0   0               4                 0               4
# 3646     0     1      0   0              11                 0               5
# 5594     0     1      1   0               3                 0               5
# 1090     1     1      0   0              14                 0               8
# 2016     0     2      1   0               0                 0               1
#
#       Violence_score
# 1457           -1.22
# 1380           -2.26
# 2975           -2.03
# 6704           -1.96
# 4053           -2.02
# ...              ...
# 251            -2.18
# 3646           -1.74
# 5594           -1.82
# 1090           -1.07
# 2016           -3.63
#
# [3445 rows x 8 columns]

# %%
HF_test = X_test[(X_test['raceC'] == 2) & (X_test['sexC'] == 1)]

# %%
HF_test
# Out:
#                      name  FirstName   LastName     sex DateOfBirth  age  \
# 50       graciela quevedo   graciela    quevedo  Female   8/15/1952   63
# 89        sharon muriente     sharon   muriente  Female   5/12/1971   44
# 127          jessica ruiz    jessica       ruiz  Female   6/15/1985   30
# 243          andrea rojas     andrea      rojas  Female  10/16/1984   31
# 319        helen carrillo      helen   carrillo  Female    6/9/1992   23
# ...                   ...        ...        ...     ...         ...  ...
# 6718         cony bonilla       cony    bonilla  Female   6/21/1991   24
# 6736      jazmin gonzalez     jazmin   gonzalez  Female  10/12/1993   22
# 6741     priscilla chavez  priscilla     chavez  Female   3/20/1990   26
# 6809      euridice mullen   euridice     mullen  Female   2/27/1966   50
# 6888  florencia sanmartin  florencia  sanmartin  Female  12/18/1992   23
#
#           race  juv_fel_count  decile_score  juv_misd_count  ...   end  event  \
# 50    Hispanic              0             1               0  ...   800      0
# 89    Hispanic              0             1               0  ...   955      0
# 127   Hispanic              0             5               0  ...    37      1
# 243   Hispanic              0             2               0  ...  1119      0
# 319   Hispanic              0             3               0  ...   824      1
# ...        ...            ...           ...             ...  ...   ...    ...
# 6718  Hispanic              0             3               0  ...  1117      0
# 6736  Hispanic              0             4               0  ...  1033      0
# 6741  Hispanic              0             4               0  ...   842      0
# 6809  Hispanic              0             3               0  ...    12      1
# 6888  Hispanic              0             4               0  ...   258      0
#
#       two_year_recid  Violence_score Recidivism_score  MarriageStatus  sexC  \
# 50                 0           -4.23            -2.51         Widowed     1
# 89                 0           -3.71            -2.20         Married     1
# 127                1           -1.91            -0.77          Single     1
# 243                0           -2.88            -1.55         Married     1
# 319                0           -2.10            -1.03          Single     1
# ...              ...             ...              ...             ...   ...
# 6718               0           -2.32            -1.20          Single     1
# 6736               0           -1.99            -1.01          Single     1
# 6741               0           -2.40            -0.52          Single     1
# 6809               1           -3.62            -1.30       Separated     1
# 6888               1           -2.12            -0.85          Single     1
#
#       ageC  raceC  MC
# 50       3      2   3
# 89       2      2   1
# 127      1      2   0
# 243      1      2   1
# 319      1      2   0
# ...    ...    ...  ..
# 6718     1      2   0
# 6736     1      2   0
# 6741     1      2   0
# 6809     2      2   2
# 6888     1      2   0
#
# [100 rows x 30 columns]

# %%
HF_train = X_train[(X_train['raceC'] == 2) & (X_train['sexC'] == 1)]

# %%
HF_train.shape
# Out:
# (57, 8)

# %%
num = 0
for index, row in X_test.iterrows():
    if int(row['sexC']) == 1 and int(row['raceC']) == 2:
        if clf.predict([row.to_list()]) != y_test.loc[index]:
            num = num + 1
            print ('-----------------')
            print (str(num) + '\n')
            print (row)
        
print(num)
print((1-num/len(HF_test))*100)
# Out:
# -----------------
# 1
#
# sexC                1.00
# ageC                2.00
# raceC               2.00
# MC                  1.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -4.13
# Name: 2692, dtype: float64
# -----------------
# 2
#
# sexC                1.00
# ageC                1.00
# raceC               2.00
# MC                  0.00
# priors_count_C      5.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.89
# Name: 1626, dtype: float64
# -----------------
# 3
#
# sexC                1.00
# ageC                1.00
# raceC               2.00
# MC                  1.00
# priors_count_C      3.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.63
# Name: 2015, dtype: float64
# -----------------
# 4
#
# sexC                1.00
# ageC                1.00
# raceC               2.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      7.00
# Violence_score     -1.41
# Name: 910, dtype: float64
# -----------------
# 5
#
# sexC                1.00
# ageC                1.00
# raceC               2.00
# MC                  0.00
# priors_count_C      2.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.58
# Name: 1504, dtype: float64
# -----------------
# 6
#
# sexC                1.00
# ageC                1.00
# raceC               2.00
# MC                  2.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      2.00
# Violence_score     -2.78
# Name: 2253, dtype: float64
# -----------------
# 7
#
# sexC                1.0
# ageC                1.0
# raceC               2.0
# MC                  2.0
# priors_count_C      0.0
# is_violent_recid    0.0
# v_decile_score      2.0
# Violence_score     -2.6
# Name: 2090, dtype: float64
# -----------------
# 8
#
# sexC                1.00
# ageC                1.00
# raceC               2.00
# MC                  0.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      3.00
# Violence_score     -2.35
# Name: 1081, dtype: float64
# -----------------
# 9
#
# sexC                1.00
# ageC                2.00
# raceC               2.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.77
# Name: 857, dtype: float64
# -----------------
# 10
#
# sexC                1.00
# ageC                1.00
# raceC               2.00
# MC                  1.00
# priors_count_C      0.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.43
# Name: 3461, dtype: float64
# -----------------
# 11
#
# sexC                1.0
# ageC                1.0
# raceC               2.0
# MC                  0.0
# priors_count_C      0.0
# is_violent_recid    0.0
# v_decile_score      5.0
# Violence_score     -1.9
# Name: 1441, dtype: float64
# -----------------
# 12
#
# sexC                1.00
# ageC                2.00
# raceC               2.00
# MC                  0.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.68
# Name: 5089, dtype: float64
# -----------------
# 13
#
# sexC                1.00
# ageC                2.00
# raceC               2.00
# MC                  2.00
# priors_count_C      1.00
# is_violent_recid    0.00
# v_decile_score      1.00
# Violence_score     -3.62
# Name: 6809, dtype: float64
# -----------------
# 14
#
# sexC                1.00
# ageC                2.00
# raceC               2.00
# MC                  0.00
# priors_count_C      9.00
# is_violent_recid    0.00
# v_decile_score      6.00
# Violence_score     -1.54
# Name: 1664, dtype: float64
# 14
# 67.44186046511628
