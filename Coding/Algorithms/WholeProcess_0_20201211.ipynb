# %% [raw]
# The whole process
#
# - train a ml model
# - use the model to test
# - find mis-classified tuples
# - apply NewAlg / NaiveAlg

# %%
# %load_ext autoreload
# %autoreload 2


import pandas as pd
import pattern_count
import NewAlg_0_20201128 as newalg
import NaiveAlg_0_20201111 as naivealg
import WholeProcess_0_20201211 as wholeprocess
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Adult dataset
# pure naive alg, 6 att, 4 min
# pure naive alg, 7 att, 22 min
# new alg, 13 att, 20min

original_data_file = "../../InputData/AdultDataset/CleanAdult2.csv"
Thc = 30
time_limit = 60*60
num_attributes = 7
original_data = pd.read_csv(original_data_file)
selected_attributes = original_data.columns.tolist()[:num_attributes]
#selected_attributes = ['age', 'education', 'marital-status', 'race', 'gender', 'workclass', 'relationship', 'occupation']
pattern_with_low_accuracy, num_patterns_checked, execution_time, overall_acc, Tha, mis_class_data = \
    wholeprocess.WholeProcessWithOneAlgorithm(original_data_file, selected_attributes, Thc, time_limit,
                                              naivealg.NaiveAlg, 'income')

print(pattern_with_low_accuracy, "\n", num_patterns_checked, execution_time, overall_acc, Tha)
# Out:
# /Users/jinyangli/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py:4170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# [[1, 3, 8, -1, -1, -1, -1], [1, 3, -1, 11, -1, -1, -1], [1, -1, 10, -1, 0, -1, -1], [1, -1, -1, 16, 0, -1, -1], [-1, 1, 8, -1, -1, 10, -1], [-1, 1, -1, 11, -1, 10, -1], [-1, -1, 8, -1, 2, 10, -1], [-1, -1, 10, -1, 0, 9, -1], [-1, -1, 8, -1, -1, 10, 0], [-1, -1, -1, 11, 2, 10, -1], [-1, -1, -1, 16, 0, 9, -1], [-1, -1, -1, 11, -1, 10, 0], [1, 5, 9, -1, -1, 0, -1], [2, 3, 11, -1, -1, -1, 0], [1, 5, -1, 13, -1, 0, -1], [2, 3, -1, 9, -1, -1, 0], [-1, 4, 12, -1, 2, 9, -1], [-1, 5, 9, -1, 2, 9, -1], [-1, 4, -1, 14, 2, 9, -1], [-1, 5, -1, 13, 2, 9, -1], [1, 2, 9, -1, 0, 3, 4], [1, 2, -1, 13, 0, 3, 4]]
# ...

# %%
print(len(pattern_with_low_accuracy))
# Out:
# 913

# %%
original_data_file = "../../InputData/AdultDataset/CleanAdult2.csv"
Thc = 30
time_limit = 60*10
num_attributes = 3
original_data = pd.read_csv(original_data_file)
selected_attributes = original_data.columns.tolist()[:num_attributes]
#selected_attributes = ['age', 'education', 'marital-status', 'race', 'gender', 'workclass', 'relationship', 'occupation']
sanity_check, pattern_with_low_accuracy1, num_patterns_checked1, execution_time1, \
    num_pattern_skipped_mis_c1, num_pattern_skipped_whole_c1, pattern_with_low_accuracy2, \
    num_patterns_checked2, execution_time2, \
    overall_acc, Tha, mis_class_data = \
    wholeprocess.WholeProcessWithTwoAlgorithms(original_data_file, selected_attributes, Thc, time_limit, 'income')



print(pattern_with_low_accuracy, "\n", num_patterns_checked, execution_time, overall_acc, Tha)
# Out:
# /Users/jinyangli/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py:4170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# sanity check fails!
# ...

# %%
original_data = pd.read_csv(original_data_file, delimiter=', *', engine='python')
less_attribute_data = original_data[selected_attributes]

original_pattern_count = pattern_count.PatternCounter(original_data, selected_attributes, encoded=False)
misclass_pattern_count = pattern_count.PatternCounter(mis_class_data, selected_attributes, encoded=False)
original_pattern_count.parse_data()
misclass_pattern_count.parse_data()

# %%
for p in pattern_with_low_accuracy:
    p_ = pattern_count.num2string(p)
    cardinality_whole_data = original_pattern_count.pattern_count(p_)
    cardinality_mis_class = misclass_pattern_count.pattern_count(p_)
    acc = (cardinality_whole_data - cardinality_mis_class) / cardinality_whole_data
    print(p, acc, cardinality_whole_data, cardinality_mis_class)
# Out:
# [1, 15, 2, 0, -1] 0.6111111111111112 18 7

# %%
pattern_with_low_accuracy, num_patterns_checked, execution_time, OverallAccuracy, Tha, mis_class_data = wholeprocess.WholeProcess(original_data_file, selected_attributes, Thc, naivealg.NaiveAlg)

print(pattern_with_low_accuracy, "\n", num_patterns_checked, execution_time, OverallAccuracy, Tha)
# Out:
# /Users/jinyangli/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py:4170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# ----------------------------------------------------  num_att =  1
# ----------------------------------------------------  num_att =  2
# ----------------------------------------------------  num_att =  3
# ----------------------------------------------------  num_att =  4
# 1
# ----------------------------------------------------  num_att =  5
# execution time = 1.0828578472137451 seconds
# 1
# num_pattern_checked =  12239
# [[1, 15, 2, 0, -1]]
#  12239 1.0828578472137451 0.8183185175357127 0.6183185175357127

# %%
original_data_file = "../../InputData/CleanAdult2.csv"
Thc = 40
time_limit = 60*16
num_attributes = 8
original_data = pd.read_csv(original_data_file)
selected_attributes = original_data.columns.tolist()[:num_attributes]
#selected_attributes = ['age', 'education', 'marital-status', 'race', 'gender', 'workclass', 'relationship', 'occupation']
pattern_with_low_accuracy, num_patterns_checked, execution_time, OverallAccuracy, Tha, mis_class_data = \
    wholeprocess.WholeProcess(original_data_file, selected_attributes, Thc, time_limit, naivealg.NaiveAlg)

print(pattern_with_low_accuracy, "\n", num_patterns_checked, execution_time, OverallAccuracy, Tha)
# Out:
# /Users/jinyangli/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py:4170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# [[1, -1, 10, -1, 0, -1, -1, -1], [1, -1, -1, 16, 0, -1, -1, -1], [-1, 1, 8, -1, -1, -1, 0, -1], [-1, 1, -1, 11, -1, -1, 0, -1], [-1, -1, 8, -1, 2, 10, -1, -1], [-1, -1, 8, -1, -1, 10, 0, -1], [-1, -1, -1, 11, 2, 10, -1, -1], [-1, -1, -1, 11, -1, 10, 0, -1], [2, 3, 11, -1, -1, -1, 0, -1], [2, 3, -1, 9, -1, -1, 0, -1], [-1, 1, 8, -1, 2, -1, -1, 4], [-1, 1, -1, 11, 2, -1, -1, 4], [1, 5, -1, -1, 2, 0, -1, 4]]
#  2868207 977.1591131687164 0.8103135641944186 0.6103135641944186

# %%
original_data_file = "../../InputData/CleanAdult2.csv"
Thc = 30
time_limit = 60*10
selected_attributes = ['age', 'education', 'marital-status', 'race', 'gender', 'workclass']
#selected_attributes = ['age', 'education', 'marital-status', 'race', 'gender', 'workclass', 'relationship', 'occupation']
pattern_with_low_accuracy1, num_patterns_checked1, execution_time1, OverallAccuracy1, Tha1, mis_class_data1 = \
    wholeprocess.WholeProcess(original_data_file, selected_attributes, Thc, time_limit, newalg.GraphTraverse)

print(pattern_with_low_accuracy1, "\n", num_patterns_checked1, execution_time1, OverallAccuracy1, Tha1)
# Out:
# /Users/jinyangli/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py:4170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# [[-1, 8, 2, -1, -1, 1], [-1, 8, 2, 2, 1, -1], [1, -1, 2, 2, -1, 5], [1, 9, 0, 4, 1, 2], [0, 9, 2, -1, -1, 0]]
#  7270 0.9599580764770508 0.8179647074432799 0.6179647074432799

# %%
original_data_file = "../../InputData/CleanAdult2.csv"
Thc = 30
time_limit = 60*10
selected_attributes = ['age', 'education', 'marital-status', 'race', 'gender', 'workclass']
#selected_attributes = ['age', 'education', 'marital-status', 'race', 'gender', 'workclass', 'relationship', 'occupation']
pattern_with_low_accuracy2, num_patterns_checked2, execution_time2, OverallAccuracy2, Tha2, mis_class_data2 = \
    wholeprocess.WholeProcess(original_data_file, selected_attributes, Thc, time_limit, naivealg.NaiveAlg)

print(pattern_with_low_accuracy2, "\n", num_patterns_checked2, execution_time2, OverallAccuracy2, Tha2)
# Out:
# /Users/jinyangli/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py:4170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# [[-1, 8, 2, -1, -1, 1], [0, 9, 2, -1, -1, 0], [1, -1, 2, 2, -1, 5], [-1, 8, 2, 2, 1, -1], [1, 9, 0, 4, 1, 2]]
#  97919 12.04568600654602 0.8178320286586175 0.6178320286586174

# %%
len1 = len(pattern_with_low_accuracy1)
len2 = len(pattern_with_low_accuracy2)
sanity = wholeprocess.ComparePatternSets(pattern_with_low_accuracy1, pattern_with_low_accuracy2)
print(sanity, len1, len2)
# Out:
# True 5 5

# %%
for p in pattern_with_low_accuracy2:
    found = False
    for q in pattern_with_low_accuracy1:
        if newalg.PatternEqual(p, q):
            found = True
            break
    if found is False:
        print('{} is not found'.format(p))

# %%
for p in pattern_with_low_accuracy1:
    found = False
    for q in pattern_with_low_accuracy2:
        if newalg.PatternEqual(p, q):
            found = True
            break
    if found is False:
        print('{} is not found'.format(p))

# %% [markdown]
# ### Credit card data

# %%
original_data_file = "../../InputData/CreditcardDataset/credit_card_clients_categorized.csv"
Thc = 30
time_limit = 60*10
#selected_attributes = ['limit_bal', 'sex', 'education', 'marriage', 'age', 'pay_0', 'pay_2']
selected_attributes = ['limit_bal', 'sex', 'education', 'marriage', 'age', 'pay_0']

pattern_with_low_accuracy1, num_calculation1, execution_time1, OverallAccuracy1, Tha1, mis_class_data1 = \
    wholeprocess.WholeProcessWithOneAlgorithm(original_data_file, selected_attributes, Thc,
                                              time_limit, newalg.GraphTraverse, 'default payment next month')

print(pattern_with_low_accuracy1, "\n", num_patterns_checked1, execution_time1, OverallAccuracy1, Tha1)
# Out:
# /Users/jinyangli/opt/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py:4170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
